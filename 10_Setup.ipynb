# %% [markdown]
# # Set environment

# %%
source("config_deseq.R")
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats
#
# Attaching package: ‘foreach’
#
# The following objects are masked from ‘package:purrr’:
#
#     accumulate, when
#
# Loading required package: S4Vectors
# Loading required package: stats4
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
# ...

# %% [markdown]
# set up directories

# %%
dir(DATDIR)
# Out:
#   [1] "B_16_S26_L001_R1_short_introns_Aligned.sortedByCoord.out.bam"
#   [2] "B_16_S26_L001_R1_short_introns_Aligned.sortedByCoord.out.bam.bai"
#   [3] "B_16_S26_L001_R1_short_introns_Log.final.out"
#   [4] "B_16_S26_L001_R1_short_introns_Log.out"
#   [5] "B_16_S26_L001_R1_short_introns_Log.progress.out"
#   [6] "B_16_S26_L001_R1_short_introns_ReadsPerGene.out.tab"
#   [7] "B_16_S26_L001_R1_short_introns_SJ.out.tab"
#   [8] "B_16_S26_L002_R1_short_introns_Aligned.sortedByCoord.out.bam"
#   [9] "B_16_S26_L002_R1_short_introns_Aligned.sortedByCoord.out.bam.bai"
#  [10] "B_16_S26_L002_R1_short_introns_Log.final.out"
#  [11] "B_16_S26_L002_R1_short_introns_Log.out"
#  [12] "B_16_S26_L002_R1_short_introns_Log.progress.out"
#  [13] "B_16_S26_L002_R1_short_introns_ReadsPerGene.out.tab"
#  [14] "B_16_S26_L002_R1_short_introns_SJ.out.tab"
#  [15] "B_16_S26_L003_R1_short_introns_Aligned.sortedByCoord.out.bam"
#  [16] "B_16_S26_L003_R1_short_introns_Aligned.sortedByCoord.out.bam.bai"
# ...

# %%
dir.create(CURDIR)
dir.create(OUTDIR)
dir.create(IMGDIR)

# %%
dir(CURDIR)
# Out:
# [1] "img" "out"
